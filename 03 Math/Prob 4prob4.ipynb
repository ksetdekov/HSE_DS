# %% [markdown]
# <a href="https://colab.research.google.com/github/ksetdekov/HSE_DS/blob/master/03%20Math/Prob%204prob4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
exp3 = np.random.exponential(1/3, 1000000)
exp12 = np.random.exponential(1/12, 1000000)

# %%
count, bins, ignored = plt.hist(exp3, 14, density = True)
plt.show()

# %%
np.mean(exp3)
# Out:
# 0.33358941477121695

# %%
np.corrcoef(exp3,exp12)
# Out:
# array([[1.00000000e+00, 4.78896995e-04],
#        [4.78896995e-04, 1.00000000e+00]])

# %%
plt.scatter(exp3, exp12, alpha=0.5)
plt.show()
